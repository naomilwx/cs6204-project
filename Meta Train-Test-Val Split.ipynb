# %% [markdown]
# ## VinDR
# Get label co-occurance matrix to determine how the classes should be split. Ideally labels that often occur together should go into the same group.

# %%
import seaborn as sns
import pandas as pd
info = pd.read_pickle('data/vindr_cxr_labels.pkl')
cols = ['Aortic enlargement', 'Atelectasis',
       'Calcification', 'Cardiomegaly', 'Clavicle fracture', 'Consolidation',
       'Edema', 'Emphysema', 'Enlarged PA', 'ILD', 'Infiltration',
       'Lung Opacity', 'Lung cavity', 'Lung cyst', 'Mediastinal shift',
       'Nodule/Mass', 'Pleural effusion', 'Pleural thickening', 'Pneumothorax',
       'Pulmonary fibrosis', 'Rib fracture', 'Other lesion', 'COPD',
       'Lung tumor', 'Pneumonia', 'Tuberculosis', 'Other diseases',
       'No finding']
corr = info[cols].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_019c1_row0_col0, #T_019c1_row1_col1, #T_019c1_row2_col2, #T_019c1_row3_col3, #T_019c1_row4_col4, #T_019c1_row5_col5, #T_019c1_row6_col6, #T_019c1_row7_col7, #T_019c1_row8_col8, #T_019c1_row9_col9, #T_019c1_row10_col10, #T_019c1_row11_col11, #T_019c1_row12_col12, #T_019c1_row13_col13, #T_019c1_row14_col14, #T_019c1_row15_col15, #T_019c1_row16_col16, #T_019c1_row17_col17, #T_019c1_row18_col18, #T_019c1_row19_col19, #T_019c1_row20_col20, #T_019c1_row21_col21, #T_019c1_row22_col22, #T_019c1_row23_col23, #T_019c1_row24_col24, #T_019c1_row25_col25, #T_019c1_row26_col26, #T_019c1_row27_col27 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col1, #T_019c1_row0_col20, #T_019c1_row14_col18, #T_019c1_row17_col27, #T_019c1_row24_col12 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col2, #T_019c1_row2_col11, #T_019c1_row4_col19, #T_019c1_row6_col17, #T_019c1_row8_col11, #T_019c1_row18_col24, #T_019c1_row21_col2, #T_019c1_row21_col25, #T_019c1_row23_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_019c1_row0_col3 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col4, #T_019c1_row1_col7, #T_019c1_row1_col8, #T_019c1_row9_col7, #T_019c1_row16_col22, #T_019c1_row18_col8, #T_019c1_row22_col18, #T_019c1_row24_col7, #T_019c1_row26_col13 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col5, #T_019c1_row3_col8, #T_019c1_row8_col9, #T_019c1_row8_col10, #T_019c1_row13_col10, #T_019c1_row16_col18, #T_019c1_row25_col12 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_019c1_row0_col6, #T_019c1_row1_col22, #T_019c1_row2_col6, #T_019c1_row3_col22, #T_019c1_row6_col4, #T_019c1_row7_col4, #T_019c1_row8_col4, #T_019c1_row8_col13, #T_019c1_row12_col4, #T_019c1_row13_col4, #T_019c1_row18_col4, #T_019c1_row22_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col7, #T_019c1_row4_col1, #T_019c1_row10_col20, #T_019c1_row17_col12, #T_019c1_row22_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col8, #T_019c1_row1_col18, #T_019c1_row5_col14, #T_019c1_row9_col1, #T_019c1_row10_col14, #T_019c1_row15_col1, #T_019c1_row18_col2, #T_019c1_row20_col5, #T_019c1_row21_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_019c1_row0_col9, #T_019c1_row6_col21, #T_019c1_row8_col24, #T_019c1_row21_col9, #T_019c1_row22_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_019c1_row0_col10, #T_019c1_row6_col19, #T_019c1_row9_col27, #T_019c1_row13_col21, #T_019c1_row16_col1, #T_019c1_row22_col21 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_019c1_row0_col11, #T_019c1_row10_col0, #T_019c1_row11_col3, #T_019c1_row19_col10, #T_019c1_row19_col16, #T_019c1_row19_col21, #T_019c1_row26_col15 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T
{
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_019c1_row1_col10, #T_019c1_row4_col16, #T_019c1_row5_col1, #T_019c1_row6_col16, #T_019c1_row7_col24, #T_019c1_row8_col15, #T_019c1_row11_col9, #T_019c1_row13_col24, #T_019c1_row13_col25, #T_019c1_row15_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_019c1_row1_col11, #T_019c1_row8_col27, #T_019c1_row12_col17, #T_019c1_row23_col3, #T_019c1_row26_col10 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_019c1_row1_col12, #T_019c1_row5_col20, #T_019c1_row7_col8, #T_019c1_row19_col13, #T_019c1_row20_col18, #T_019c1_row22_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_019c1_row1_col13, #T_019c1_row3_col12, #T_019c1_row5_col13, #T_019c1_row10_col22, #T_019c1_row13_col6, #T_019c1_row24_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_019c1_row1_col14, #T_019c1_row1_col24, #T_019c1_row5_col10, #T_019c1_row6_col0, #T_019c1_row7_col27, #T_019c1_row10_col3, #T_019c1_row11_col25, #T_019c1_row12_col0, #T_019c1_row13_col0, #T_019c1_row21_col24, #T_019c1_row24_col25, #T_019c1_row25_col15 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_019c1_row1_col15, #T_019c1_row2_col27, #T_019c1_row4_col21, #T_019c1_row7_col25, #T_019c1_row15_col5, #T_019c1_row24_col1, #T_019c1_row26_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_019c1_row1_col16, #T_019c1_row2_col15, #T_019c1_row9_col3, #T_019c1_row18_col0, #T_019c1_row22_col0, #T_019c1_row24_col21 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_019c1_row1_col17, #T_019c1_row4_col27, #T_019c1_row13_col27, #T_019c1_row14_col0, #T

# %% [markdown]
# ## Meta Split
# Split data into meta train/test/validation sets. Images that have train or validation labels are excluded from the meta-train set.

# %%
import pandas as pd
import numpy as np

from utils.labels import VINDR_SPLIT

info = pd.read_pickle('data/vindr_cxr_labels.pkl')
allocations_vindr = {}
for i in range(len(info)):
    df = info.iloc[i]
    res = []
    for s in ['train', 'test', 'val']:
        if df[VINDR_SPLIT[s]].sum() > 0:
            res.append(s)
    allocations_vindr[df['image_id']] = res

for f, s in allocations_vindr.items():
    if len(s) == 1:
        info.loc[info['image_id'] == f, 'meta_split'] = s[0]
        continue
    if 'val' in s and 'test' not in s:
        info.loc[info['image_id'] == f, 'meta_split'] = 'val'
        continue
    if 'test' in s and 'val' not in s:
        info.loc[info['image_id'] == f, 'meta_split'] = 'test'
        continue

    df = info[info['image_id'] == f].iloc[0]
    val_priority = ['COPD']
    if df[val_priority].sum() > 0:
        info.loc[info['image_id'] == f, 'meta_split'] = 'val'
        continue
    test_priority = ['Edema','Lung cyst','Clavicle fracture','Lung cavity']
    if df[test_priority].sum() > 0:
        info.loc[info['image_id'] == f, 'meta_split'] = 'test'
        continue
    if np.random.uniform() > 0.5:
        info.loc[info['image_id'] == f, 'meta_split'] = 'test'
    else:
        info.loc[info['image_id'] == f, 'meta_split'] = 'val'

info.to_pickle('vindr_cxr_split_labels.pkl')

# %% [markdown]
# ### Training Query Set

# %%
import pandas as pd
from utils.data import select_query_set, count_classes

info = pd.read_pickle('data/vindr_cxr_split_labels.pkl')
info = info[info['meta_split'] == 'train']

query_set, selected = select_query_set(info, VINDR_SPLIT['train'], 50)

print(len(selected))
print('query', count_classes(info[info['image_id'].isin(selected)], VINDR_SPLIT['train']))
print('support', count_classes(info[~info['image_id'].isin(selected)], VINDR_SPLIT['train']))
# Out:
# 700
# query {'No finding': 61, 'Other diseases': 573, 'Aortic enlargement': 372, 'Cardiomegaly': 273, 'Pleural thickening': 328, 'Pulmonary fibrosis': 295, 'Lung Opacity': 248, 'Other lesion': 171, 'Pneumonia': 257, 'Pleural effusion': 200, 'Tuberculosis': 164, 'Infiltration': 186, 'ILD': 132, 'Consolidation': 108}
# support {'No finding': 12569, 'Other diseases': 2611, 'Aortic enlargement': 1877, 'Cardiomegaly': 1640, 'Pleural thickening': 943, 'Pulmonary fibrosis': 696, 'Lung Opacity': 449, 'Other lesion': 401, 'Pneumonia': 347, 'Pleural effusion': 407, 'Tuberculosis': 265, 'Infiltration': 209, 'ILD': 217, 'Consolidation': 92}

# %%
import pandas as pd
from utils.data import select_query_set, count_classes
from utils.labels import VINDR_SPLIT

info = pd.read_pickle('data/vindr_cxr_split_labels.pkl')
info = info[info['meta_split'] == 'train']

query_set, selected = select_query_set(info, VINDR_SPLIT['train'], 40)

print(len(selected))
print('query', count_classes(info[info['image_id'].isin(selected)], VINDR_SPLIT['train']))
print('support', count_classes(info[~info['image_id'].isin(selected)], VINDR_SPLIT['train']))
# Out:
# 560
# query {'No finding': 45, 'Other diseases': 461, 'Aortic enlargement': 287, 'Cardiomegaly': 216, 'Pleural thickening': 249, 'Pulmonary fibrosis': 240, 'Lung Opacity': 197, 'Other lesion': 135, 'Pneumonia': 199, 'Pleural effusion': 164, 'Tuberculosis': 127, 'Infiltration': 147, 'ILD': 97, 'Consolidation': 89}
# support {'No finding': 12585, 'Other diseases': 2723, 'Aortic enlargement': 1962, 'Cardiomegaly': 1697, 'Pleural thickening': 1022, 'Pulmonary fibrosis': 751, 'Lung Opacity': 500, 'Other lesion': 437, 'Pneumonia': 405, 'Pleural effusion': 443, 'Tuberculosis': 302, 'Infiltration': 248, 'ILD': 252, 'Consolidation': 111}

# %%
import pickle
with open('vindr_train_query_set.pkl', 'wb') as fp:
    pickle.dump(query_set, fp)

# %% [markdown]
# ## MuReD

# %%
import seaborn as sns
import pandas as pd
info = pd.read_pickle('data/mured_labels.pkl')
cols = ['DR', 'NORMAL', 'MH', 'ODC', 'TSLN', 'ARMD', 'DN', 'MYA', 'BRVO', 'ODP', 'CRVO', 'CNV', 'RS', 'ODE', 'LS', 'CSR', 'HTR', 'ASR', 'CRS', 'OTHER']
corr = info[cols].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8cc75_row0_col0, #T_8cc75_row1_col1, #T_8cc75_row2_col2, #T_8cc75_row3_col3, #T_8cc75_row4_col4, #T_8cc75_row5_col5, #T_8cc75_row6_col6, #T_8cc75_row7_col7, #T_8cc75_row8_col8, #T_8cc75_row9_col9, #T_8cc75_row10_col10, #T_8cc75_row11_col11, #T_8cc75_row12_col12, #T_8cc75_row13_col13, #T_8cc75_row14_col14, #T_8cc75_row15_col15, #T_8cc75_row16_col16, #T_8cc75_row17_col17, #T_8cc75_row18_col18, #T_8cc75_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8cc75_row3_col7, #T_8cc75_row16_col11, #T_8cc75_row16_col19 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8cc75_row3_col10, #T_8cc75_row3_col11, #T_8cc75_row3_col13 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_8cc75_row3_col19, #T_8cc75_row9_col7, #T_8cc75_row19_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8cc75_row4_col0, #T_8cc75_row16_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8cc75_row4_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_8cc75_row4_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_8cc75_row4_col5, #T_8cc75_row5_col4, #T_8cc75_row17_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8cc75_row4_col6, #T_8cc75_row4_col9, #T_8cc75_row6_col4, #T_8cc75_row7_col1, #T_8cc75_row10_col19, #T_8cc75_row15_col19, #T_8cc75_row17_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8cc75_row4_col19, #T_8cc75_row9_col2, #T_8cc75_row9_col3, #T_8cc75_row12_col3, #T_8cc75_row14_col6, #T_8cc75_row16_col3, #T_8cc75_row17_col3, #T_8cc75_row17_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_8cc75_row5_col3, #T_8cc75_row5_col19, #T_8cc75_row10_col3, #T_8cc75_row11_col3, #T_8cc75_row13_col3, #T_8cc75_row14_col4, #T_8cc75_row19_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_8cc75_row5_col7, #T_8cc75_row17_col16 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_8cc75_row5_col8, #T_8cc75_row6_col8, #T_8cc75_row7_col11, #T_8cc75_row8_col9, #T_8cc75_row8_col11, #T_8cc75_row8_col12, #T_8cc75_row8_col13, #T_8cc75_row10_col14, #T_8cc75_row11_col10 {
#   backgrou

# %% [markdown]
# Split data into meta train/test/validation sets

# %%
import pandas as pd
import numpy as np

from utils.labels import MURED_SPLIT

info = pd.read_pickle('data/mured_labels.pkl')
allocations_mured = {}
for i in range(len(info)):
    df = info.iloc[i]
    res = []
    for s in ['train', 'test', 'val']:
        if df[MURED_SPLIT[s]].sum() > 0:
            res.append(s)
    allocations_mured[df['image_id']] = res

val_test_classes = {}
for f, s in allocations_mured.items():
    if len(s) == 1:
        info.loc[info['image_id'] == f, 'meta_split'] = s[0]
        continue
    if 'val' in s and 'test' not in s:
        info.loc[info['image_id'] == f, 'meta_split'] = 'val'
        continue
    
    info.loc[info['image_id'] == f, 'meta_split'] = 'test'

for s in ['train', 'test', 'val']:
    print(s, len(info[info['meta_split'] == s]))

info.to_pickle('mured_split_labels.pkl')
# Out:
# train 1746
# test 230
# val 232

# %%
import pandas as pd
from utils.data import select_query_set, count_classes

info = pd.read_pickle('data/mured_split_labels.pkl')
info = info[info['meta_split'] == 'train']

query_set, selected = select_query_set(info, MURED_SPLIT['train'], 10)

print(len(selected))
print('query', count_classes(info[info['image_id'].isin(selected)], MURED_SPLIT['train']))
print('support', count_classes(info[~info['image_id'].isin(selected)], MURED_SPLIT['train']))
# Out:
# 100
# query {'DR': 17, 'NORMAL': 10, 'ODC': 22, 'OTHER': 17, 'MH': 13, 'DN': 14, 'ARMD': 20, 'TSLN': 17, 'MYA': 11, 'CNV': 13}
# support {'DR': 417, 'NORMAL': 482, 'ODC': 218, 'OTHER': 205, 'MH': 147, 'DN': 133, 'ARMD': 125, 'TSLN': 123, 'MYA': 72, 'CNV': 37}

# %%
import pickle
with open('mured_train_query_set.pkl', 'wb') as fp:
    pickle.dump(query_set, fp)
